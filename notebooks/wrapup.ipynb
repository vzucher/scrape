# %%
# Scraper

# Login
# Input Hashtag or Hashtags 
# Search Hashtag[0] "instagram.com/explore/tags/${hashtag}"
# Parse each grid's post -> Extract username 
# Build Dictionary { username: URL }

# Verify if is_tattoo_artist? 

# parse username
# parse bio
# 

# Instaloader

# For each username, browse to URL, request download for all profile's data
# Create datalake, upload all profile's information there
# Create structured SQL database with all tattoo artist's of Brazil # email + telefone? 

# Enrich DB

# Query tattoo artist's name/username on Google, try to find phone+email

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://conexaoisrael.org"

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(url, headers=headers, verify=False)
# Out:
# /Users/vzucher/.pyenv/versions/lewagon/lib/python3.10/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'conexaoisrael.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
soup
# Out:
# <head><title>Not Acceptable!</title></head><body><h1>Not Acceptable!</h1><p>An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.</p></body>
